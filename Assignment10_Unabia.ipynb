# %% [markdown]
# <a href="https://colab.research.google.com/github/GeIoace/LinearAlgebra/blob/main/Assignment10_Unabia.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Linear Algebra for ECE**
# ## **Laboratory 10** : *Linear Combination and Vector Spaces*

# %% [markdown]
# *Now that you have a fundamental knowledge about linear combination, we'll try to visualize it using scientific programming.*

# %% [markdown]
# ### **Objectives**
# At the end of this activity you will be able to:
# 1. *Be familiar with representing linear combinations in the 2-dimensional plane.*
# 2. *Visualize spans using vector fields in Python.*
# 3. *Perform vector fields operations using scientific programming.*

# %% [markdown]
# ## **Discussion**

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ###**Linear Combination**

# %% [markdown]
# *It is said that a linear combination is the combination of linear scaling and addition of a vector its bases/components*

# %% [markdown]
# *We will try to visualize the vectors and their linear combinations by plotting a sample of real number values for the scalars for the vectors. Let's first try the vectors below:*

# %% [markdown]
# $$X = \begin{bmatrix} 2\\5 \\\end{bmatrix} , Y = \begin{bmatrix} 7\\9 \\\end{bmatrix} $$

# %%
vectX = np.array([2,5])
vectY = np.array([7,9])
vectY
# Out:
# array([7, 9])

# %% [markdown]
# #### **Span of single vectors**

# %% [markdown]
# *As discussed in the lecture, the span of individual vectors can be represented by a line span. Let's take vector $X$ as an example.*

# %% [markdown]
# $$X = c\cdot \begin{bmatrix} 2\\5 \\\end{bmatrix} $$

# %%
c = np.arange(-10,10,0.125)

plt.scatter(c*vectX[0],c*vectX[1])

plt.xlim(-10,10)
plt.ylim(-10,10)
plt.axhline(y=0, color='k')
plt.axvline(x=0, color='k')
plt.grid()
plt.show()

# %% [markdown]
# $$Y = c\cdot \begin{bmatrix} 7\\9 \\\end{bmatrix} $$

# %%
c = np.arange(-15,15,0.5)

plt.scatter(c*vectY[0],c*vectY[1])

plt.xlim(-20,20)
plt.ylim(-20,20)
plt.axhline(y=0, color='k')
plt.axvline(x=0, color='k')
plt.grid()
plt.show()

# %% [markdown]
# ###**Span of a linear combination of vectors**

# %% [markdown]
# *So what if we are to plot the span of a linear combination of vectors? We can visualize as a plane on the 2-dimensional coordinate system. Let's take the span of the linear combination below:*

# %% [markdown]
# $$S = \begin{Bmatrix} c_1 \cdot\begin{bmatrix} 1\\0 \\\end{bmatrix},
# c_2 \cdot \begin{bmatrix} 1\\-1 \\\end{bmatrix}\end{Bmatrix} $$

# %%
vectA = np.array([1,0])
vectB = np.array([1,-1])

R = np.arange(-10,10,1)

c1, c2 = np.meshgrid(R,R)

vectR = vectA + vectB
spanRx = c1*vectA[0] + c2*vectB[0]
spanRy = c1*vectA[1] + c2*vectB[1]
##plt.scatter(R*vectA[0],R*vectA[1])
##plt.scatter(R*vectB[0],R*vectB[1])
plt.scatter(spanRx,spanRy, s=5, alpha=0.75)

plt.axhline(y=0, color='k')
plt.axvline(x=0, color='k')
plt.grid()
plt.show()

# %%
vectP = np.array([2,1])
vectQ = np.array([4,3])

R = np.arange(-10,10,1)

c1, c2 = np.meshgrid(R,R)

vectR = vectP + vectQ
spanRx = c1*vectP[0] + c2*vectQ[0]
spanRy = c1*vectP[1] + c2*vectQ[1]
##plt.scatter(R*vectA[0],R*vectA[1])
##plt.scatter(R*vectB[0],R*vectB[1])
plt.scatter(spanRx,spanRy, s=5, alpha=0.75)

plt.axhline(y=0, color='k')
plt.axvline(x=0, color='k')
plt.grid()
plt.show()

# %% [markdown]
# *Take note that if vectors are seen to be as a 2-dimensional span we can say it has a Rank of 2 or $\mathbb{R}^2$. But if the span of the linear combination of vectors are seen to be like a line, they are said to be <b> linearly dependent </b> and they have a rank of 1 or $\mathbb{R}^1$.*

# %% [markdown]
# ##**Activity**

# %% [markdown]
# ###**Task 1**

# %% [markdown]
# Try different linear combinations using different scalar values. In your methodology discuss the different functions that you have used, the  linear equation and vector form of the linear combination, and the flowchart for declaring and displaying linear combinations. Please make sure that your flowchart has only few words and not putting the entire code as it is bad practice. In your results, display and discuss the linear combination visualization you made. You should use the cells below for displaying the equation markdows using LaTeX and your code.

# %% [markdown]
# $$V = \begin{bmatrix} 5\\8 \\\end{bmatrix} , E = \begin{bmatrix} 5\\5 \\\end{bmatrix} $$

# %%
vectV = np.array([5,8])
vectE = np.array([5,5])
vectE
# Out:
# array([5, 5])

# %% [markdown]
# #### ***Span of single vectors***

# %% [markdown]
# $$N = C\cdot \begin{bmatrix} 5\\3 \\\end{bmatrix} $$

# %%
C = np.arange(-16,25,.65)

plt.scatter(C*vectE[0],C*vectE[0])

plt.xlim(-20,20)
plt.ylim(-20,20)
plt.axhline(y=0, color='k')
plt.axvline(x=0, color='k')
plt.grid()
plt.show()

# %% [markdown]
# $$B = C\cdot \begin{bmatrix} 7\\9 \\\end{bmatrix} $$

# %%
C = np.arange(-13,35,.25)

plt.scatter(C*vectV[0],C*vectV[0])

plt.xlim(-25,25)
plt.ylim(-25,25)
plt.axhline(y=0, color='k')
plt.axvline(x=0, color='k')
plt.grid()
plt.show()

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #### ***Span of linear combination of vectors***

# %% [markdown]
# $$M = \begin{Bmatrix} c_1 \cdot\begin{bmatrix} 8\\4 \\\end{bmatrix},
# c_2 \cdot \begin{bmatrix} 5\\-3 \\\end{bmatrix}\end{Bmatrix} $$

# %% [markdown]
# $$
#  7x-3y-44z=0
# $$

# %%
vectO = np.array([8,4])
vectP = np.array([5,-3])

M = np.arange(-22,14,2)

c1, c2 = np.meshgrid(M,M)

vectM = vectV + vectE
spanMx = c1*vectO[0] + c2*vectP[0]
spanMy = c1*vectO[1] + c2*vectP[1]
##plt.scatter(R*vectA[0],R*vectA[1])
##plt.scatter(R*vectB[0],R*vectB[1])
plt.scatter(spanMx,spanMy, s=5, alpha=0.75)

plt.axhline(y=0, color='k')
plt.axvline(x=0, color='k')
plt.grid()
plt.show()

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Conclusion guide

# %% [markdown]
# For your conclusion synthesize the concept and application of the laboratory. Briefly discuss what you have learn and achieved in this activity. At the end of your conclusion try to answer the question : "How can you apply the concept of linear combination in engineering or real-life situations?".
#
#
#
# > During the previous lab experiments, we gained new and different insights wherein it is applicable to this lab reprot that tackles linear combination, and vector spaces. It is important to consider a lot of things when coding at this current lab report because plotting a graph is involved. Similar to the previous lab experiments, it is important that we run the previous line of codes in order for the program to run as you intend it to. and avoid errors.
#
# > Matrices, Vectors, and Linear Combinations are used to solve common engineering, and physics problem involving distance, speed, time, and velocity.
